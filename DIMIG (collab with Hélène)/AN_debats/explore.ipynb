# %%
import pandas as pd 
import os 
from pathlib import Path

# %%
corpus = pd.read_csv(Path(os.getcwd()) / "data/corpus_debats_2015_2025.csv", index_col=0)

# %%
corpus.head()
# Out:
#                             attachmentUrl     dateSeance   dateParution  \
# id
# ANSETEXT000053324357      AN_2025-142.pdf  1766448000000  1766534400000
# ANSETEXT000053324355  AN_2025-142_Bis.pdf  1766448000000  1766534400000
# ANSETEXT000053324356      AN_2025-141.pdf  1766016000000  1766102400000
# ANSETEXT000053324354  AN_2025-141_Bis.pdf  1766016000000  1766102400000
# ANSETEXT000053314220      AN_2025-140.pdf  1765929600000  1766016000000
#
#                       anneeParution typeAssemblee              origine  \
# id
# ANSETEXT000053324357           2025            AN  Assemblée nationale
# ANSETEXT000053324355           2025        AN_BIS  Assemblée nationale
# ANSETEXT000053324356           2025            AN  Assemblée nationale
# ANSETEXT000053324354           2025        AN_BIS  Assemblée nationale
# ANSETEXT000053314220           2025            AN  Assemblée nationale
#
#                       legislature    session nomSession pathToFile  \
# id
# ...

# %%
corpus[corpus["typeAssemblee"] == "AN"]["content"].iloc[32]
# Out:
# 'ASSEMBLÉE \nNATIONALE \n\nJOURNAL OFFICIEL DE LA RÉPUBLIQUE FRANÇAISE \n\nXVIIe Législature  \n\nSESSION ORDINAIRE DE 2025-2026 \n\nSéances du jeudi 30 octobre 2025 \n\nCompte rendu intégral \n\nLes articles, amendements et annexes figurent dans le fascicule bleu ci-joint \n\nhttp://www.assemblee-nationale.fr \n\nAnnée 2025. – No 110 A.N. (C.R.) ISSN 2493-2086 Vendredi 31 octobre 2025 \n\n\n\nSOMMAIRE GÉNÉRAL  \n\n1re séance . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  8341 \n\n2e séance . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  8379 \n\n3e séance . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .  8429      \n\n\n\nASSEMBLÉE \nNATIONALE \n\nJOURNAL OFFICIEL DE LA RÉPUBLIQUE FRANÇAISE \n\
# ...

# %%
# %pip install ijson
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\rorod\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Si besoin: %pip install ijson
import ijson
from itertools import islice

json_path = Path(os.getcwd()) / "data/liste_debats_2015_2025.json"

with open(json_path, "rb") as f:
    premiers_objets = list(islice(ijson.items(f, "item"), 10))

metadata_debats = pd.DataFrame(premiers_objets)
metadata_debats.head()
# Out:
#                      id                  idEli              origine  \
# 0  ANSETEXT000053324357      eli/ancr/2025/142  Assemblée nationale
# 1  ANSETEXT000053324355  eli/ancr/2025/142_bis  Assemblée nationale
# 2  ANSETEXT000053324356      eli/ancr/2025/141  Assemblée nationale
# 3  ANSETEXT000053324354  eli/ancr/2025/141_bis  Assemblée nationale
# 4  ANSETEXT000053314220      eli/ancr/2025/140  Assemblée nationale
#
#       dateSeance   dateParution  anneeParution typeAssemblee  legislature  \
# 0  1766448000000  1766534400000           2025            AN           17
# 1  1766448000000  1766534400000           2025        AN_BIS           17
# 2  1766016000000  1766102400000           2025            AN           17
# 3  1766016000000  1766102400000           2025        AN_BIS           17
# 4  1765929600000  1766016000000           2025            AN           17
#
#    numeroParution nomSession    session        attachmentUrl  \
# ...
